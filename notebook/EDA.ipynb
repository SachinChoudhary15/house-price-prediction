# %% [markdown]
# ## First import libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("../data/raw/kc_house_data.csv")

# %% [markdown]
# ### See dataset

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608      1530.0              0      2009             0    98103  47.6993
# 21609      2310.0              0      2014             0    98146  47.5107
# 21610      1020.0              0      2009             0    98144  47.5944
# 21611      1600.0              0      2004             0    98027  47.5345
# 21612      1020.0              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(6), int64(14), object(1)
# memory usage: 3.5+ MB

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21611.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.396095     291.509045   1971.005136     84.402258
# std        1.175459    828.128162     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above       float64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# ### Check null values

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       2
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ### Check duplicates and drop them

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df["bedrooms"].value_counts()
# Out:
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: count, dtype: int64

# %%
df["bathrooms"].value_counts()
# Out:
# bathrooms
# 2.50    5380
# 1.00    3852
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1446
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      72
# 4.75      23
# 5.00      21
# 5.25      13
# 0.00      10
# 5.50      10
# 1.25       9
# 6.00       6
# 0.50       4
# 5.75       4
# 6.75       2
# 8.00       2
# 6.50       2
# 6.25       2
# 7.75       1
# 7.50       1
# Name: count, dtype: int64

# %%
df["condition"].value_counts()
# Out:
# condition
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: count, dtype: int64

# %%
df["floors"].value_counts()
# Out:
# floors
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: count, dtype: int64

# %%
df["grade"].value_counts()
# Out:
# grade
# 7     8981
# 8     6068
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      90
# 4       29
# 13      13
# 3        3
# 1        1
# Name: count, dtype: int64

# %%
df["lat"].value_counts()
# Out:
# lat
# 47.6846    17
# 47.6624    17
# 47.5491    17
# 47.5322    17
# 47.6711    16
#            ..
# 47.2581     1
# 47.6047     1
# 47.3008     1
# 47.4295     1
# 47.2962     1
# Name: count, Length: 5034, dtype: int64

# %%
df["long"].value_counts()
# Out:
# long
# -122.290    116
# -122.300    111
# -122.362    104
# -122.291    100
# -122.372     99
#            ...
# -121.316      1
# -121.941      1
# -121.480      1
# -121.767      1
# -122.420      1
# Name: count, Length: 752, dtype: int64

# %%
df["sqft_above"].value_counts()
# Out:
# sqft_above
# 1300.0    212
# 1010.0    210
# 1200.0    206
# 1220.0    192
# 1140.0    184
#          ...
# 3906.0      1
# 4073.0      1
# 2578.0      1
# 2738.0      1
# 1606.0      1
# Name: count, Length: 946, dtype: int64

# %%
df["sqft_basement"].value_counts()
# Out:
# sqft_basement
# 0       13126
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 176         1
# 225         1
# 1275        1
# 274         1
# 248         1
# Name: count, Length: 306, dtype: int64

# %%
df["sqft_living"].value_counts()
# Out:
# sqft_living
# 1300    138
# 1400    135
# 1440    133
# 1660    129
# 1800    129
#        ...
# 2398      1
# 2656      1
# 3281      1
# 1458      1
# 1572      1
# Name: count, Length: 1038, dtype: int64

# %%
df["sqft_living15"].value_counts()
# Out:
# sqft_living15
# 1540    197
# 1440    195
# 1560    192
# 1500    181
# 1460    169
#        ...
# 2513      1
# 2725      1
# 1955      1
# 2527      1
# 4443      1
# Name: count, Length: 777, dtype: int64

# %%
df["sqft_lot"].value_counts()
# Out:
# sqft_lot
# 5000     358
# 6000     290
# 4000     251
# 7200     220
# 4800     120
#         ...
# 2642       1
# 2656       1
# 15035      1
# 638        1
# 13405      1
# Name: count, Length: 9782, dtype: int64

# %%
df["sqft_lot15"].value_counts()
# Out:
# sqft_lot15
# 5000    427
# 4000    357
# 6000    289
# 7200    211
# 4800    145
#        ...
# 5259      1
# 3836      1
# 5009      1
# 1395      1
# 5761      1
# Name: count, Length: 8689, dtype: int64

# %%
df["view"].value_counts()
# Out:
# view
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: count, dtype: int64

# %%
df["waterfront"].value_counts()
# Out:
# waterfront
# 0    21450
# 1      163
# Name: count, dtype: int64

# %%
df["yr_built"].value_counts()
# Out:
# yr_built
# 2014    559
# 2006    454
# 2005    450
# 2004    433
# 2003    422
#        ...
# 1933     30
# 1901     29
# 1902     27
# 1935     24
# 1934     21
# Name: count, Length: 116, dtype: int64

# %%
df["yr_renovated"].value_counts()
# Out:
# yr_renovated
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1948        1
# 1951        1
# 1959        1
# 1934        1
# 1944        1
# Name: count, Length: 70, dtype: int64

# %%
df["zipcode"].value_counts()
# Out:
# zipcode
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: count, Length: 70, dtype: int64

# %% [markdown]
# ### Visualize dataset

# %%
sns.barplot(x="bedrooms", y="price", data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
sns.histplot(x="price", data=df, bins=30, hue="bedrooms", kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x = df["price"], legend="auto")
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# ### Scaling with log transformation

# %%
df["price"] = np.log(df["price"])

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x = df["price"], legend="auto")
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# ### Detect and remove outliers

# %%
Q1 = df["price"].quantile(0.25)
Q3 = df["price"].quantile(0.75)
IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

df = df[(df["price"] >= lower_limit) & (df["price"] <= upper_limit)]

# %%
print(f"Remaining outliers: {df[(df['price'] < lower_limit) | (df['price'] > upper_limit)].shape[0]}")
# Out:
# Remaining outliers: 0

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x = df["price"], legend="auto")
# Out:
# <Axes: xlabel='price'>

# %%
df.shape
# Out:
# (21280, 21)

# %%
df = df[(df["bedrooms"] > 0) & (df["bedrooms"] <= 10)]

# %%
df["bedrooms"].value_counts()
# Out:
# bedrooms
# 3     9772
# 4     6748
# 2     2724
# 5     1523
# 6      257
# 1      190
# 7       32
# 8       10
# 9        6
# 10       3
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (21265, 21)

# %% [markdown]
# ## Training model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

from sklearn.model_selection import train_test_split, RandomizedSearchCV

# %%
x = df.drop("price", axis=1)
y = df["price"]

# %% [markdown]
# ### Separate numerical and categorical columns

# %%
# We only have numeric columns so we do not need columnTransfer
num_cols = x.select_dtypes(include=["int64", "float64"]).columns

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("scaler", StandardScaler(), num_cols)
    ]
)

# %% [markdown]
# ### Create ML pipeline

# %%
from sklearn.pipeline import Pipeline

# %%
# Decision Tree pipeline
dtr_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("model", DecisionTreeRegressor())
])

# %%
rfr_pipeline = Pipeline([
    ("preprocessor", preprocessor), 
    ("model", RandomForestRegressor())
])

# %% [markdown]
# ### train test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Hyperparameter tuning with RandomizedSearchCV

# %%
param_distributions = {
    "model__max_depth": [None, 10, 20, 30],
    "model__min_samples_split": [2, 5, 10],
    "model__min_samples_leaf": [1, 2, 4],
    "model__max_features": ['sqrt', 'log2']
}
random_search_dtr = RandomizedSearchCV(
    estimator=dtr_pipeline,
    param_distributions=param_distributions,
    n_iter=10,
    cv=5,
    verbose=2,
    random_state=42,
    n_jobs=1
)
random_search_dtr.fit(x_train, y_train)
print("Best Hyperparameters:", random_search_dtr.best_params_)
best_dtr = random_search_dtr.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=10; total time=   0.0s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=10; total time=   0.0s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=10; total time=   0.0s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=10; total time=   0.0s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=10; total time=   0.0s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=10; total time=   0.0s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=10; total time=   0.0s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=10; total time=   0.0s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=10; total time=   0.0s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=10; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=5; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=None, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2; total time=   0.0s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2; total time=   0.0s
# Best Hyperparameters: {'model__min_samples_split': 10, 'model__min_samples_leaf': 4, 'model__max_features': 'sqrt', 'model__max_depth': 30}

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
y_train_pred_dtr = best_dtr.predict(x_train)
y_test_pred_dtr = best_dtr.predict(x_test)

dtr_train_r2 = r2_score(y_train, y_train_pred_dtr)
dtr_test_r2 = r2_score(y_test, y_test_pred_dtr)

rmse = np.sqrt(mean_squared_error(y_test, y_test_pred_dtr))
mae = mean_absolute_error(y_test, y_test_pred_dtr)

print(f"dtr_train_r2: {dtr_train_r2}\n")
print(f"dtr_test_r2: {dtr_test_r2}\n")
print(f"rmse: {rmse}\n")
print(f"mae: {mae}\n")
print(f"Overfitting_ Gap: {dtr_train_r2 - dtr_test_r2}\n")
print(f"Best Hyperparameters: {random_search_dtr.best_params_}\n")
# Out:
# dtr_train_r2: 0.9162860088939745
#
# dtr_test_r2: 0.773902609776159
#
# rmse: 0.2325027489328784
#
# mae: 0.16985542915465426
#
# Overfitting_ Gap: 0.1423833991178155
#
# Best Hyperparameters: {'model__min_samples_split': 10, 'model__min_samples_leaf': 4, 'model__max_features': 'sqrt', 'model__max_depth': 30}

# %%
param_distributions = {
    "model__n_estimators": [100, 200, 300],
    "model__max_depth": [None, 10, 20, 30],
    "model__min_samples_split": [2, 5, 10],
    "model__min_samples_leaf": [1, 2, 4],
    "model__max_features": ['sqrt', 'log2']
}

random_search_rfr = RandomizedSearchCV(
    estimator=rfr_pipeline,
    param_distributions=param_distributions,
    n_iter=10,
    cv=5,
    verbose=2,
    random_state=42,
    n_jobs=1
)

random_search_rfr.fit(x_train, y_train)
print("Best Hyperparameters:", random_search_rfr.best_params_)
best_rfr = random_search_rfr.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END model__max_depth=30, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   3.6s
# [CV] END model__max_depth=30, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   3.2s
# [CV] END model__max_depth=30, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   3.3s
# [CV] END model__max_depth=30, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   3.1s
# [CV] END model__max_depth=30, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   3.1s
# [CV] END model__max_depth=30, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=100; total time=   2.6s
# [CV] END model__max_depth=30, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=100; total time=   2.5s
# [CV] END model__max_depth=30, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=100; total time=   2.6s
# [CV] END model__max_depth=30, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=100; total time=   2.6s
# [CV] END model__max_depth=30, model__max_features=log2, model__min_samples_leaf=4, model__min_samples_split=10, model__n_estimators=100; total time=   2.7s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   3.4s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   3.2s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   3.3s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   3.2s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   3.2s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=100; total time=   2.7s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=100; total time=   2.8s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=100; total time=   2.8s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=100; total time=   2.9s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=100; total time=   2.9s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=100; total time=   2.9s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=100; total time=   2.8s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=100; total time=   2.8s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=100; total time=   2.8s
# [CV] END model__max_depth=None, model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=100; total time=   2.8s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   3.2s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   3.3s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   3.3s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   3.3s
# [CV] END model__max_depth=20, model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   3.4s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300; total time=   8.3s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300; total time=   8.0s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300; total time=   8.0s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300; total time=   8.2s
# [CV] END model__max_depth=30, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=300; total time=   8.0s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=200; total time=   3.9s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=200; total time=   3.9s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=200; total time=   3.9s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=200; total time=   3.9s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=4, model__min_samples_split=2, model__n_estimators=200; total time=   3.8s
# [CV] END model__max_depth=30, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=200; total time=   5.5s
# [CV] END model__max_depth=30, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=200; total time=   5.5s
# [CV] END model__max_depth=30, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=200; total time=   5.5s
# [CV] END model__max_depth=30, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=200; total time=   5.5s
# [CV] END model__max_depth=30, model__max_features=log2, model__min_samples_leaf=2, model__min_samples_split=10, model__n_estimators=200; total time=   5.6s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   6.3s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   6.4s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   6.3s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   6.4s
# [CV] END model__max_depth=20, model__max_features=log2, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   6.4s
# Best Hyperparameters: {'model__n_estimators': 200, 'model__min_samples_split': 5, 'model__min_samples_leaf': 1, 'model__max_features': 'log2', 'model__max_depth': 20}

# %%
y_train_pred_rfr = best_rfr.predict(x_train)
y_test_pred_rfr = best_rfr.predict(x_test)

rfr_train_r2 = r2_score(y_train, y_train_pred_rfr)
rfr_test_r2 = r2_score(y_test, y_test_pred_rfr)

rmse = np.sqrt(mean_squared_error(y_test, y_test_pred_rfr))
mae = mean_absolute_error(y_test, y_test_pred_rfr)

print(f"rfr_train_r2: {rfr_train_r2}\n")
print(f"rfr_test_r2: {rfr_test_r2}\n")
print(f"rmse: {rmse}\n")
print(f"mae: {mae}\n")
print(f"Overfitting_ Gap: {rfr_train_r2 - rfr_test_r2}\n")
print(f"Best Hyperparameters: {random_search_rfr.best_params_}\n")
# Out:
# rfr_train_r2: 0.9681912188359802
#
# rfr_test_r2: 0.8739396842040482
#
# rmse: 0.17360791154547828
#
# mae: 0.12328787861492121
#
# Overfitting_ Gap: 0.09425153463193203
#
# Best Hyperparameters: {'model__n_estimators': 200, 'model__min_samples_split': 5, 'model__min_samples_leaf': 1, 'model__max_features': 'log2', 'model__max_depth': 20}
